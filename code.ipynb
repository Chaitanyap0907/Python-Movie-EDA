# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv(r"C:\Users\CHAITHANYA\OneDrive\Desktop\projects\Python-Movie-EDA-main\Python-Movie-EDA-main\movies_dataset_5000_rows.csv")

# plot size
plt.figure(figsize=(7, 5.5))

# scatter plot
plt.scatter(df["BudgetUSD"], df["Global_BoxOfficeUSD"])

#title and axis labels
plt.title("BudgetUSD vs Global_BoxOfficeUSD")
plt.xlabel("BudgetUSD")
plt.ylabel("Global_BoxOfficeUSD")

plt.savefig('my_output_image.png', dpi=300, bbox_inches='tight')
# Display
plt.show()
